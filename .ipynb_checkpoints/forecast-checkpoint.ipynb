# %%
import pandas as pd
import numpy as np
import math
from time import sleep as fallasleep
import os, sys

# %%
import krakenex
from pykrakenapi import KrakenAPI

# %%
color_box = ['#1f77b4','#ff7f0e','#2ca02c','#d62728',
             '#9467bd','#8c564b','#e377c2','#7f7f7f',
             '#bcdb22','#17becf']

# %%
api = krakenex.API()
k = KrakenAPI(api)
coins = ["ETH", "BTC", "XRP", "ADA", "DOT"]
gapmin= 1440
coins = [coin+"USD" for coin in coins]
df = {}
colormapper = {}
for _,coin in enumerate(coins):
    data, last = k.get_ohlc_data(coin, interval = gapmin, ascending = True)
    df[coin]=data.drop(['time', 'count'], axis=1)
    colormapper[coin] = color_box[_]
    fallasleep(1)

# %% [markdown]
# ##### Recall from `causation.ipynb` that price of the Bitcoin can be predicted with using all other 4 coins.

# %%
df["BTCUSD"].head(3)
# Out:
#               open    high     low   close    vwap        volume
# dtime
# 2019-11-20  8124.9  8220.0  8030.0  8083.1  8104.1   3329.920133
# 2019-11-21  8083.1  8116.5  7399.0  7619.1  7703.1   7275.881648
# 2019-11-22  7619.1  7719.3  6761.0  7284.8  7225.4  13608.745363

# %%
df["BTCUSD"] = df["BTCUSD"].apply(np.log).diff().dropna()

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
Y = df["BTCUSD"]['close'].values
X = df["BTCUSD"].drop(['close'], axis=1).values

# %%
print(X.shape, Y.shape)
# Out:
# (719, 5) (719,)

# %%
# fig = plt.figure(figsize=(8,6))
fig, ax = plt.subplots(len(df["BTCUSD"].columns),1,figsize=(10,25))
for _,col in enumerate(df["BTCUSD"]):
    ax[_].scatter(df["BTCUSD"][col], Y)
    ax[_].set_title(f"{col} vs close price")
#     ax[_].set_ylabel("rate of return")
#     ax[_].set_xlabel("Date")
#     ax[_].grid()
# fig.autofmt_xdate()
plt.show()

# %% [markdown]
# ##### volume doesn't impact the price

# %%
lm = linear_model.LinearRegression()

# %%
Y = df["BTCUSD"]['close'].values
X = df["BTCUSD"].drop(['close', 'volume'], axis=1).values

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
test_len = math.floor(len(X)*0.2)
X_train, X_test, y_train, y_test = X[:-test_len], X[-test_len:], Y[:-test_len], Y[-test_len:]

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (576, 4) (143, 4) (576,) (143,)

# %%
model = lm.fit(X_train, y_train)
predictions = model.predict(X_test)
print(f"Predictions: {predictions}")
print(f"R^2 value:   {lm.score(X, Y)}")
print(f"coedd:       {lm.coef_}")
print(f"intercept:   {lm.intercept_}")
# Out:
# Predictions: [ 2.30957829e-03 -2.52471828e-02 -7.46951881e-02  8.13762979e-03
#   7.86015255e-02 -1.30374026e-02 -4.42587516e-02 -9.26097502e-03
#   5.56914177e-02  7.04911857e-03  4.58330873e-02 -4.95342925e-02
#  -3.15047025e-02  1.72067217e-02  3.43961458e-02  2.04676617e-02
#  -5.39842800e-02  2.81296474e-02  7.26707609e-03 -5.14167405e-02
#   2.80375483e-02  1.09015904e-03  1.92217174e-02 -2.66306219e-02
#  -8.67130557e-03 -7.34531346e-03 -1.52431496e-02  1.01797445e-02
#   2.71953512e-03  2.91694906e-03 -2.94974291e-02 -3.08900141e-02
#   8.28170285e-02 -1.05013153e-02  1.07044662e-02  2.68274753e-02
#   1.16331283e-02  1.04468635e-01 -3.97904226e-02  3.10811179e-02
#  -6.81200246e-03  6.08878040e-03  1.94862130e-02 -1.76348894e-03
#  -2.73454195e-02 -2.41001432e-02  3.13104448e-02 -8.98650837e-03
#   5.60137692e-02  2.53481516e-02 -1.53959731e-03  3.64384024e-02
#  -2.24948003e-02  2.42185593e-02 -3.39253044e-02  5.92602779e-02
#  -2.61943001e-02 -6.87039010e-03  1.14972005e-02 -9.33324730e-03
#  -6.36853689e-05  6.62767052e-03  4.29590753e-02 -6.21124963e-03
#   1.87740816e-03  2.09852350e-02 -2.80043181e-02  9.16640938e-03
#  -3.85844336e-02  3.90233591e-02  2.12226460e-03 -1.31114628e-03
#  -1.56482076e-02  5.11970150e-03  1.46003118e-02  2.29810139e-02
#   6.12679333e-03 -8.40437549e-03  2.09167213e-02  3.77752451e-03
#  -9.19545655e-02  1.02578751e-02  2.02692539e-02 -2.61866103e-02
#   1.34908917e-02  6.20790336e-03 -3.25933490e-02  5.26195377e-02
#   1.21933353e-02 -9.87845256e-03 -2.43746264e-03  2.47649928e-02
#  -2.61260338e-02 -7.41436863e-02 -1.25434792e-02  5.40979335e-02
#   3.90171093e-03 -5.62269979e-02  2.46955865e-02  7.65625635e-03
#   1.27921832e-02 -3.12074336e-02  1.53025067e-02  3.56787613e-02
#   5.91772268e-02 -1.62875005e-02  1.28349534e-02 -1.82166998e-03
#   3.99550964e-02  4.37947036e-02 -1.99835108e-02  2.42135266e-02
#   3.46486662e-03 -1.39779216e-03  3.72239726e-02 -3.89544698e-02
#   1.14659462e-02  2.16915438e-02  5.29064601e-02 -2.00193902e-02
#  -4.45634220e-03  1.79109859e-02  1.79353291e-02  2.90954267e-02
#  -4.22780256e-02 -4.64837736e-03 -1.00485758e-03 -1.52290107e-02
#   4.67792810e-02 -3.79408648e-02 -2.16350819e-02  3.75580494e-02
#   8.85093850e-03 -1.57753493e-02 -4.12369261e-03  6.60114806e-03
#   4.00279718e-02 -2.80251892e-02 -1.38966023e-02  1.01373975e-02
#  -4.47282887e-03  2.07596693e-02  3.06205042e-02]
# R^2 value:   0.7289464681559201
# coedd:       [-0.52678748 -0.0863512  -0.04277219  1.28457187]
# intercept:   0.0009668583551258388

# %%
df["BTCUSD"].head(3)
# Out:
#                 open      high       low     close      vwap    volume
# dtime
# 2019-11-21 -0.005158 -0.012671 -0.081840 -0.059117 -0.050747  0.781617
# 2019-11-22 -0.059117 -0.050175 -0.090174 -0.044868 -0.064020  0.626148
# 2019-11-23 -0.044882 -0.050398  0.049656  0.005175  0.002530 -1.372126

# %%
df["BTCUSD"].index[-len(y_test):]
# Out:
# DatetimeIndex(['2021-06-19', '2021-06-20', '2021-06-21', '2021-06-22',
#                '2021-06-23', '2021-06-24', '2021-06-25', '2021-06-26',
#                '2021-06-27', '2021-06-28',
#                ...
#                '2021-10-30', '2021-10-31', '2021-11-01', '2021-11-02',
#                '2021-11-03', '2021-11-04', '2021-11-05', '2021-11-06',
#                '2021-11-07', '2021-11-08'],
#               dtype='datetime64[ns]', name='dtime', length=143, freq='1440T')

# %%
plt.plot(df["BTCUSD"]['close'].values)

# %%
fig = plt.figure(figsize=(10,4))
plt.plot(df["BTCUSD"].index[:len(y_train)], y_train, color='black', alpha=0.5, lw=2)
plt.plot(df["BTCUSD"].index[-len(y_test):], y_test, color='blue', alpha=0.5, lw=2)
plt.plot(df["BTCUSD"].index[-len(y_test):], predictions, color='red', alpha=0.3, lw=1)
fig.autofmt_xdate()

# %%
plt.scatter(y_test, predictions)
plt.show()
